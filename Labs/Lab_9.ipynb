# %%
#!curl http://archive.ics.uci.edu/ml/machine-learning-databases/00279/SUSY.csv.gz > SUSY.csv.gz

# %%
filename="SUSY.csv.gz"
# print out the first 5 lines using unix head command
# !head -5  "SUSY.csv.gz"
# Out:
# ��y�5�Ķ�}�c:5�X[�'������m?��;�{�ϕ����:����mw�rl��F��<G��n�l�����i�}c�[\�|��Y�-����x�OX�m�UK��/��
# b}�'�'v��$[��N�5��l'�}�m�a�j���h/1��{��K��+�1f[��I���9��w�V�D�O,f�:�;'��`��*{�g�訲�e��mO���[TV,<�]����� m�ZPDu��5�V�o������:��,k�r	R]_��A�"��n�B�K����X�t�W��\x@���g�ݟe����gn�v�}�e5Ͷd=k�*<�:�܍�7U�%�0��aK��zH��U�?O���n[�����r2��ڑ�r��v��]��, xW(_�휶��l�ZV���B�=�i��ڦ�%��¾%4e�d�ٶ��F,2W�
# �z3לKD�bo���mc�����R"�d[$luza�ɾ�{N�X?�,w����hqU?F;v��lG�8!Ų'~Î�lYZ�p��y��س=n{_���n�|GҶ,�pؖʽ��Xm�ڷ�k(����}��k� k��n�S���}`G�=oK,,���ǒ/�Q�$<[{�
# �vdY�9Nj��[�NlyY�x��}UV������Ú���ID��
# =V��{�'G�$�,����b	�ַ�;m[$���c�ā�����Gr���_[��5�דR�X�=7B�bǔ�Z��%��9�e^T�Z��Q�/�u�YV;�,����qnq�B\�����Z�k{�ᤴ��h��V�sJ8���f8�a�N$۾�%,8��~

# %%
VarNames=["signal", "l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi", "MET", "MET_phi", "MET_rel", "axial_MET", "M_R", "M_TR_2", "R", "MT2", "S_R", "M_Delta_R", "dPhi_r_b", "cos_theta_r1"]

# %%
RawNames=["l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi"]
 
FeatureNames=[ "l_2_phi", "MET", "MET_phi", "MET_rel", "axial_MET", "M_R", "M_TR_2", "R", "MT2", "S_R", "M_Delta_R", "dPhi_r_b", "cos_theta_r1"]

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(filename, dtype='float64', names=VarNames)

# %%
df
# Out:
#          signal    l_1_pT   l_1_eta   l_1_phi    l_2_pT   l_2_eta   l_2_phi  \
# 0           0.0  0.972861  0.653855  1.176225  1.157156 -1.739873 -0.874309
# 1           1.0  1.667973  0.064191 -1.225171  0.506102 -0.338939  1.672543
# 2           1.0  0.444840 -0.134298 -0.709972  0.451719 -1.613871 -0.768661
# 3           1.0  0.381256 -0.976145  0.693152  0.448959  0.891753 -0.677328
# 4           1.0  1.309996 -0.690089 -0.676259  1.589283 -0.693326  0.622907
# 5           0.0  0.456398  1.099371  1.512453  0.751772  0.638967 -0.742216
# 6           0.0  0.437818 -1.119883 -1.336823  0.502320 -1.717515  1.017067
# 7           0.0  0.571656  0.205696  0.425950  0.578514  0.927399 -1.101478
# 8           1.0  2.112812  0.742983 -0.330539  0.805253 -0.028887 -1.446679
# 9           0.0  1.001869 -0.471788  0.555614  1.233368  1.255548 -1.052491
# 10          0.0  0.840115  0.958249 -0.585658  1.317930 -1.063730  1.246235
# ...

# %% [markdown]
# *Exercise 4.1*
#
#
# Train the Fisher performance of using the raw, features, and raw+features as input. Compare the performance one a single plot. Add cells to this notebook as needed.

# %%
import sklearn.discriminant_analysis as DA
Fisher=DA.LinearDiscriminantAnalysis()
N_Train=4000000

Train_Sample=df[:N_Train]
Test_Sample=df[N_Train:]

X1_Train=Train_Sample[RawNames[0:]]
y1_Train=Train_Sample["signal"]

X1_Test=Test_Sample[RawNames[0:]]
y1_Test=Test_Sample["signal"]

Test_sig=Test_Sample[Test_Sample.signal==1]
Test_bkg=Test_Sample[Test_Sample.signal==0]
Fisher.fit(X1_Train,y1_Train)
plt.figure()
plt.hist(Fisher.decision_function(Test_sig[RawNames[0:]]),bins=100,histtype="step", color="blue", label="signal",stacked=True)
plt.hist(Fisher.decision_function(Test_bkg[RawNames[0:]]),bins=100,histtype="step", color="red", label="background",stacked=True)
plt.legend(loc='upper right')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, _ = roc_curve(y1_Test, Fisher.decision_function(X1_Test))

roc_auc = auc(fpr, tpr)

plt.plot(fpr,tpr,color='darkorange',label='ROC curve (area = %0.2f)' % roc_auc)
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.show()

# %%
import sklearn.discriminant_analysis as DA
Fisher=DA.LinearDiscriminantAnalysis()
N_Train=4000000

Train_Sample=df[:N_Train]
Test_Sample=df[N_Train:]

X2_Train=Train_Sample[FeatureNames[0:]]
y2_Train=Train_Sample["signal"]

X2_Test=Test_Sample[FeatureNames[0:]]
y2_Test=Test_Sample["signal"]

Test_sig=Test_Sample[Test_Sample.signal==1]
Test_bkg=Test_Sample[Test_Sample.signal==0]
Fisher.fit(X2_Train,y2_Train)
plt.figure()
plt.hist(Fisher.decision_function(Test_sig[FeatureNames[0:]]),bins=100,histtype="step", color="blue", label="signal",stacked=True)
plt.hist(Fisher.decision_function(Test_bkg[FeatureNames[0:]]),bins=100,histtype="step", color="red", label="background",stacked=True)
plt.legend(loc='upper right')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, _ = roc_curve(y2_Test, Fisher.decision_function(X2_Test))

roc_auc = auc(fpr, tpr)

plt.plot(fpr,tpr,color='darkorange',label='ROC curve (area = %0.2f)' % roc_auc)
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.show()

# %%
together=FeatureNames+RawNames

# %%
N_Train=4000000

Train_Sample=df[:N_Train]
Test_Sample=df[N_Train:]

X3_Train=Train_Sample[together[0:]]
y3_Train=Train_Sample["signal"]

X3_Test=Test_Sample[together[0:]]
y3_Test=Test_Sample["signal"]

Test_sig=Test_Sample[Test_Sample.signal==1]
Test_bkg=Test_Sample[Test_Sample.signal==0]
########################
Fisher.fit(X3_Train,y3_Train)
########################
plt.figure()
plt.hist(Fisher.decision_function(Test_sig[together[0:]]),bins=100,histtype="step", color="blue", label="signal",stacked=True)
plt.hist(Fisher.decision_function(Test_bkg[together[0:]]),bins=100,histtype="step", color="red", label="background",stacked=True)
plt.legend(loc='upper right')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, _ = roc_curve(y3_Test, Fisher.decision_function(X3_Test))

roc_auc = auc(fpr, tpr)

plt.plot(fpr,tpr,color='darkorange',label='ROC curve (area = %0.2f)' % roc_auc)
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.show()

# %% [markdown]
# **Exercise 4.2**

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import roc_curve, auc
reg = PassiveAggressiveClassifier()

reg.fit(X1_Train,y1_Train)
fpraw, tpraw, _ = roc_curve(y1_Test, reg.decision_function(X1_Test))
roc_auc1 = auc(fpraw, tpraw)
 
reg.fit(X2_Train,y2_Train)
fprf, tprf, _ = roc_curve(y2_Test, reg.decision_function(X2_Test))
roc_auc2 = auc(fprf, tprf)
 

reg.fit(X3_Train,y3_Train)
fprb, tprb, _ = roc_curve(y3_Test, reg.decision_function(X3_Test))
 
roc_auc3 = auc(fprb, tprb)


plt.plot(fpraw,tpraw,color='red',label='raw ROC curve  (area = %0.2f)' % roc_auc1)
plt.plot(fprf,tprf,color='blue',label='feature ROC curve (area = %0.2f)' % roc_auc2)
plt.plot(fprb,tprb,color='yellow',label='both ROC curve (area = %0.2f)' % roc_auc3)
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("both")
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.passive_aggressive.PassiveAggressiveClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %% [markdown]
# from sklearn import svm
# reg = svm.SVC()
# reg.fit(X1_Train,y1_Train)
# fpraw, tpraw, _ = roc_curve(y1_Test, reg.decision_function(X1_Test))
# roc_auc1 = auc(fpraw, tpraw)
#
# reg.fit(X2_Train,y2_Train)
# fprf, tprf, _ = roc_curve(y2_Test, reg.decision_function(X2_Test))
# roc_auc2 = auc(fprf, tprf)
#
#
# reg.fit(X3_Train,y3_Train)
# fprb, tprb, _ = roc_curve(y3_Test, reg.decision_function(X3_Test))
#
# roc_auc3 = auc(fprb, tprb)
#
#
# plt.plot(fpraw,tpraw,color='red',label='raw ROC curve  (area = %0.2f)' % roc_auc1)
# plt.plot(fprf,tprf,color='blue',label='feature ROC curve (area = %0.2f)' % roc_auc2)
# plt.plot(fprb,tprb,color='yellow',label='both ROC curve (area = %0.2f)' % roc_auc3)
# plt.legend(loc="lower right")
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title("both")
# plt.show()

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import roc_curve, auc
pas=LinearSVC()

pas.fit(X1_Train,y1_Train)
pasfpraw, pastpraw, _ = roc_curve(y1_Test, pas.decision_function(X1_Test))
roc_aucr = auc(pasfpraw, pastpraw)

pas.fit(X2_Train,y2_Train)
fprpas, tprpas, _ = roc_curve(y2_Test, pas.decision_function(X2_Test))
roc_aucf = auc(fprpas, tprpas)
 
pas.fit(X3_Train,y3_Train)
fprbp, tprbp, _ = roc_curve(y3_Test, pas.decision_function(X3_Test))
roc_aucb = auc(fprbp, tprbp)


plt.plot(pasfpraw,pastpraw,color='green',label='ROC curve RAW (area = %0.2f)' % roc_aucr)
plt.plot(fprpas,tprpas,color='orange',label='ROC curve FEATURE (area = %0.2f)' % roc_aucf)
plt.plot(fprbp,tprbp,color='purple',label='ROC curve (area = %0.2f)' % roc_aucb)
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.show()

# %% [markdown]
# **Exercise 4.3**

# %%
import numpy as np
def PlotSignificance(N_S,N_B, N_S_min=1):
    plt.figure()
    eff_sig,bins_sig,p_sig=plt.hist(Fisher.decision_function(Test_sig[VarNames[:]]),bins=100,histtype="step", color="blue", label="signal",cumulative=-1,stacked=True,normed=True)
    eff_bkg,bins_bkg,p_bkg=plt.hist(Fisher.decision_function(Test_bkg[VarNames[:]]),bins=100,histtype="step", color="red", label="background",cumulative=-1,stacked=True,normed=True)
    plt.legend(loc='upper right')
    plt.show()
    
    good_bins = np.where(eff_sig*N_S>=N_S_min)

    print (len(good_bins[0]))
    if len(good_bins[0])<1:
        print ("Insufficient Signal.")
        return 0,0,0
    
    significance=(N_S*eff_sig)/np.sqrt((N_B*eff_bkg)+(N_S*eff_sig))

    plt.figure()
    plt.plot(bins_sig[:-1],significance)
    
    max_sign=np.max(significance[good_bins])
    max_signI=np.argmax(significance[good_bins])
    
    plt.show()
    print ("Max significance at ", bins_sig[max_signI], " of", max_sign)
    return bins_sig[max_signI],max_sign, max_signI
    
PlotSignificance(1000000,1e11)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 100
# Max significance at  -0.21999211679765907  of 148.03287422646096
# (-0.21999211679765907, 148.03287422646096, 37)

# %% [markdown]
#
# 1.What are we computing when making a normalized cummulative plot?
#
# The signifigance
#
# 2.Assume that the experiment produces 1 signal event for every $10^{11}$ background events. For each of your classifiers, how many signal events need to be produced to be able to make a $5\sigma$ discovery claim?
#
# 2.5e+12 signal events

# %%
# !print(sklearn.__version__)
